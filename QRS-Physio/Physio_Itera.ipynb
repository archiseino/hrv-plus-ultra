# %% [markdown]
# ## Physio Itera Dataset Extraction
#
# subject: Toby White Eyes Blue Dragon
#
# Whut, 3 min operations, what a lucky day for me
#
# v0.1
#
# -- Status Logging

# %%
## Import Dependencies
import numpy as np
import mediapipe as mp
import pandas as pd
import cv2
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import matplotlib.pyplot as plt
import scipy
from collections import Counter
import os
import json

# %%
# import scipy.io as sio
# f = sio.loadmat('../subject1/p1_0.mat')
# print(f.keys())

# ## Print the value features other than video and GT
# for key in f.keys():
#     if key != 'video' and key != 'GT_ppg':
#         print(key, f[key])

# %%
# ## Print the shape of the video and GT
# print(f['video'].shape)
# print(f['GT_ppg'].shape)

# %% [markdown]
# ### Extract the video Frames
#
# The videos were filmed at 30 frames per second with
# a resolution of 1280x720 pixels but were compressed to
# 320x240 pixels to facilitate storage and transmission.

# %%
# ## Import dependencies
# import os
# import cv2
# import json
# import numpy as np
# import pandas as pd

# %%
# # Create output directories
# image_folder = "../Physio-Itera/Dataset/tryx2/rgb"
# os.makedirs(image_folder, exist_ok=True)

# # # Extract video frames and GT PPG
# # video_frames = f["video"]  # Shape [t, w, h, c]
# # gt_ppg = f["GT_ppg"].flatten()  # Convert to 1D array

# # Save frames as images
# for i in range(video_frames.shape[0]):
#     frame = video_frames[i]  # Extract frame [w, h, c]
    
#     # Normalize if values are in [0,1] range
#     if frame.max() <= 1.0:
#         frame = (frame * 255).astype(np.uint8)  # Scale to 0-255

#     frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)  # Convert RGB to BGR for OpenCV
#     image_path = os.path.join(image_folder, f"frame_{i:04d}.jpg")
#     cv2.imwrite(image_path, frame)  # Save frame

# print(f"Saved {video_frames.shape[0]} images to {image_folder}")

# # Save GT PPG as JSON
# json_path = "gt_ppg.json"
# with open(json_path, "w") as json_file:
#     json.dump(gt_ppg.tolist(), json_file)

# print(f"Saved GT PPG to {json_path}")

# # Save GT PPG as Excel
# df = pd.DataFrame({"GT_ppg": gt_ppg})
# excel_path = "gt_ppg.xlsx"
# df.to_excel(excel_path, index=False)

# print(f"Saved GT PPG to {excel_path}")

# %% [markdown]
# ## Extract the GT value
# The
# PPG signals were downsampled from 200Hz to 30Hz to match
# the frame rate of the videos, resulting in 1800 frames per
# video

# %%
# import matplotlib.pyplot as plt

# # Define the sampling rate
# sampling_rate = 30  # Hz

# # Create a time array based on the sampling rate and the number of samples
# time = np.arange(len(gt_ppg)) / sampling_rate

# ## Print len of GT_PPG 
# print(len(gt_ppg))

# # Plot the GT_PPG signal
# plt.figure(figsize=(12, 6))
# plt.plot(gt_ppg, label='GT_PPG')
# plt.xlabel('Time (s)')
# plt.ylabel('PPG Signal')
# plt.title('GT_PPG Signal at 30 Hz Sampling Rate')
# plt.legend()
# plt.grid(True)
# plt.show()

# %% [markdown]
# ## Define the POS method
# Pos Method by Wenjin Wang

# %%
## Core method POS 
def POS(signal, **kargs):
    """
    POS method on CPU using Numpy.

    The dictionary parameters are: {'fps':float}.

    Wang, W., den Brinker, A. C., Stuijk, S., & de Haan, G. (2016). Algorithmic principles of remote PPG. IEEE Transactions on Biomedical Engineering, 64(7), 1479-1491. 
    """
    """
    eps: A small constant (10^-9) used to prevent division by zero in normalization steps.
    X: The input signal, which is a 3D array where:
    e: Number of estimators or regions in the frame (like different parts of the face).
    c: Color channels (3 for RGB).
    f: Number of frames.
    w: Window length, determined by the camera's frame rate (fps). For example, at 20 fps, w would be 32 (which corresponds to about 1.6 seconds of video).
    """
    eps = 10**-9
    X = signal
    e, c, f = X.shape # Number of estimators, color channels, and frames
    w = int(1.6 * kargs['fps']) # Window length in frames

    """
    P: A fixed 2x3 matrix used for the projection step. It defines how to transform the color channels (RGB) into a new space.
    Q: This is a stack of the matrix P repeated e times, where each P corresponds to an estimator (region of interest) in the video.
    """
    P = np.array([[0, 1, -1], [-2, 1, 1]])
    Q = np.stack([P for _ in range(e)], axis = 0)

    """
    H: A matrix to store the estimated heart rate signal over time for each estimator.
    n: The current frame in the sliding window.
    m: The start index of the sliding window (calculating which frames are part of the current window).
    """
    H = np.zeros((e, f))
    for n in np.arange(w, f):
        # Start index of sliding window 
        m = n - w + 1

        """
        Temporal Normalization (Equation 5 from the paper): This step ensures that the signal is invariant to global lighting changes and other noise factors.
        """
        Cn = X[:, :, m:(n+1)]
        M = 1.0 / (np.mean(Cn, axis = 2) + eps)
        M = np.expand_dims(M, axis=2) # shape [e, c, w]
        Cn = np.multiply(Cn, M)

        """
        Projection (Equation 6 from the paper): This step transforms the RGB values into a space where the signal from blood flow (heart rate) is more distinct.
        """
        S = np.dot(Q, Cn)
        S = S[0, :, :, :]
        S = np.swapaxes(S, 0, 1) 

        """
        Tuning (Equation 7 from the paper): This step adjusts the projected components to make the heart rate signal clearer.
        """
        S1 = S[:, 0, :]
        S2 = S[:, 1, :]
        alpha = np.std(S1, axis=1) / (eps + np.std(S2, axis=1))
        alpha - np.expand_dims(alpha, axis=1)
        Hn = np.add(S1, alpha * S2)
        Hnm = Hn - np.expand_dims(np.mean(Hn, axis=1), axis=1)

        """
        Overlap-Adding (Equation 8 from the paper): This step combines the processed signals from each frame to form the final output heart rate signal.
        """
        H[:, m:(n + 1)] = np.add(H[:, m:(n + 1)], Hnm)  # Add the tuned signal to the output matrix

    return H

# %% [markdown]
# ### Setup Mediapipe Cheeks ROI.
#
# Setup the functions and properties for doing the RPPGs

# %%
## Create Facelandmarker Object
base_options = python.BaseOptions(model_asset_path="../Models/face_landmarker.task")
VisionRunningMode = mp.tasks.vision.RunningMode
options = vision.FaceLandmarkerOptions(
    base_options=base_options,
    num_faces=1,
    running_mode = VisionRunningMode.IMAGE,
)
detector = vision.FaceLandmarker.create_from_options(options)

# %%
def get_cheek_rois(landmarks, image_shape):
    h, w, _ = image_shape
    left_cheek_indices = [111, 121, 50, 142]
    right_cheek_indices = [350, 340, 355, 280]

    left_cheek_points = [(int(landmarks[idx].x * w), int(landmarks[idx].y * h)) for idx in left_cheek_indices]
    right_cheek_points = [(int(landmarks[idx].x * w), int(landmarks[idx].y * h)) for idx in right_cheek_indices]

    left_cheek_rect = (
        min([pt[0] for pt in left_cheek_points]), min([pt[1] for pt in left_cheek_points]),
        max([pt[0] for pt in left_cheek_points]), max([pt[1] for pt in left_cheek_points])
    )
    print("Left Cheek Rect:", left_cheek_rect)
    right_cheek_rect = (
        min([pt[0] for pt in right_cheek_points]), min([pt[1] for pt in right_cheek_points]),
        max([pt[0] for pt in right_cheek_points]), max([pt[1] for pt in right_cheek_points])
    )
    print("Right Cheek Rect:", right_cheek_rect)

    return left_cheek_rect, right_cheek_rect

# %%
def extract_rgb_from_rect(rect, image):
    x_min, y_min, x_max, y_max = rect
    roi = image[y_min:y_max, x_min:x_max]
    return roi

# %% [markdown]
# ## v0.1
#
# Extraction the RGB Signal over the entire frame image

# %%
""" RGB Signal Variables

    Variables to store the RGB signals from the left and right cheeks,
    as well as the combined signal from both cheeks.

"""
# Lists to store RGB values
left_r_signal, left_g_signal, left_b_signal = [], [], []
right_r_signal, right_g_signal, right_b_signal = [], [], []

# Lists to store combined RGB values
combined_r_signal, combined_g_signal, combined_b_signal = [], [], []

## Utils
fs = 30 # Sampling rate in Hz for RPPG signal

# %%
video_folder="../Physio-Itera/Dataset/tryx6/rgb"
video_files = sorted(os.listdir(video_folder))

## print the len of folder
print(len(video_files))

## Get the first image
image_path = os.path.join(video_folder, video_files[0])
image = cv2.imread(image_path)

## Get the height and width
h, w, _ = image.shape

print(h, w)
# Out:
# 1800
# 1080 1920

# %%
import cv2

import matplotlib.pyplot as plt

# Get the first image
image_path = os.path.join(video_folder, video_files[0])
image = cv2.imread(image_path)

# Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

mp_image = mp.Image(
    image_format=mp.ImageFormat.SRGB,
    data=image_rgb
)

## Get the landkmarks
result = detector.detect(mp_image)

if result.face_landmarks:
    for face_landmark in result.face_landmarks:
        # Get cheek ROIs
        left_cheek_rect, right_cheek_rect = get_cheek_rois(face_landmark, image_rgb.shape)

        # Extract the RGB signals from the left and right cheeks
        left_cheek_roi = extract_rgb_from_rect(left_cheek_rect, image_rgb)
        right_cheek_roi = extract_rgb_from_rect(right_cheek_rect, image_rgb)

        print("Left Cheek ROI Shape:", left_cheek_roi.shape)
        print("Right Cheek ROI Shape:", right_cheek_roi.shape)

        # Draw both cheek ROIs with rectangles
        cv2.rectangle(image_rgb, (left_cheek_rect[0], left_cheek_rect[1]), (left_cheek_rect[2], left_cheek_rect[3]), (0, 255, 0), 2)
        cv2.rectangle(image_rgb, (right_cheek_rect[0], right_cheek_rect[1]), (right_cheek_rect[2], right_cheek_rect[3]), (0, 255, 0), 2)
        
        # Calculate mean pixel values for the RGB channels
        left_cheek_rgb = cv2.mean(left_cheek_roi)[:3]
        right_cheek_rgb = cv2.mean(right_cheek_roi)[:3]

        # Combine and average the RGB values from both cheeks
        combined_r = (left_cheek_rgb[0] + right_cheek_rgb[0]) / 2
        combined_g = (left_cheek_rgb[1] + right_cheek_rgb[1]) / 2
        combined_b = (left_cheek_rgb[2] + right_cheek_rgb[2]) / 2

        ## Print the RGB value
        print("Left Cheek RGB:", left_cheek_rgb)
        print("Right Cheek RGB:", right_cheek_rgb)
        print("Combined RGB:", (combined_r, combined_g, combined_b))

# Display the image
plt.figure(figsize=(10, 6))
plt.imshow(image_rgb)
plt.title('My honest reaction')
plt.axis('off')
plt.show()
# Out:
# Left Cheek Rect: (871, 283, 929, 316)
# Right Cheek Rect: (983, 284, 1041, 316)
# Left Cheek ROI Shape: (33, 58, 3)
# Right Cheek ROI Shape: (32, 58, 3)
# Left Cheek RGB: (158.98850574712645, 146.9775339602926, 104.75391849529781)
# Right Cheek RGB: (198.1373922413793, 180.33459051724137, 139.41002155172413)
# Combined RGB: (178.56294899425288, 163.656062238767, 122.08197002351096)

# %%
"""
Main Loop: Stuff
"""

# Load the video frames
video_folder="../Physio-Itera/Dataset/tryx6/rgb"
video_files = sorted(os.listdir(video_folder))

# Load the face landmarks
for i in range(len(video_files) - 1): ## The last one is
    # Load the image
    image_path = os.path.join(video_folder, video_files[i])
    image = cv2.imread(image_path)

    ## Detect the face area using shape
    h, w, _ = image.shape

    ## Converting into RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    ## Seting up the Mediapipe Image
    mp_image = mp.Image(
        image_format=mp.ImageFormat.SRGB,
        data=image_rgb
    )

    # Perform face landmark detection
    result = detector.detect(mp_image)

    # Extract the face landmarks
    if result.face_landmarks:
        for face_landmark in result.face_landmarks:
            # Get cheek ROIs
            left_cheek_rect, right_cheek_rect = get_cheek_rois(face_landmark, image_rgb.shape)

            # Draw both cheek ROIs with rectangles
            cv2.rectangle(image_rgb, (left_cheek_rect[0], left_cheek_rect[1]), (left_cheek_rect[2], left_cheek_rect[3]), (0, 255, 0), 2)
            cv2.rectangle(image_rgb, (right_cheek_rect[0], right_cheek_rect[1]), (right_cheek_rect[2], right_cheek_rect[3]), (0, 255, 0), 2)

            # Extract the left and right cheek ROIs
            left_cheek_roi = extract_rgb_from_rect(left_cheek_rect, image_rgb)
            right_cheek_roi = extract_rgb_from_rect(right_cheek_rect, image_rgb)

            # Calculate mean pixel values for the RGB channels
            left_cheek_rgb = cv2.mean(left_cheek_roi)[:3]
            right_cheek_rgb = cv2.mean(right_cheek_roi)[:3]

            # Combine and average the RGB values from both cheeks
            combined_r = (left_cheek_rgb[0] + right_cheek_rgb[0]) / 2
            combined_g = (left_cheek_rgb[1] + right_cheek_rgb[1]) / 2
            combined_b = (left_cheek_rgb[2] + right_cheek_rgb[2]) / 2

            # Append the combined RGB values to the respective lists
            combined_r_signal.append(combined_r)
            combined_g_signal.append(combined_g)
            combined_b_signal.append(combined_b)
# Out:
# Left Cheek Rect: (871, 283, 929, 316)
# Right Cheek Rect: (983, 284, 1041, 316)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 284, 930, 318)
# Right Cheek Rect: (984, 284, 1042, 317)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 312)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 312)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1040, 312)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (983, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (983, 281, 1041, 312)
# Left Cheek Rect: (872, 284, 930, 317)
# Right Cheek Rect: (983, 284, 1042, 317)
# Left Cheek Rect: (870, 282, 928, 313)
# Right Cheek Rect: (982, 281, 1040, 312)
# Left Cheek Rect: (870, 281, 928, 313)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 313)
# Right Cheek Rect: (982, 280, 1040, 312)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 312)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 284, 929, 318)
# Right Cheek Rect: (984, 284, 1042, 317)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 313)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (871, 284, 930, 317)
# Right Cheek Rect: (983, 284, 1041, 317)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (981, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1042, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 313)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (872, 284, 930, 317)
# Right Cheek Rect: (983, 285, 1040, 317)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 312)
# Left Cheek Rect: (871, 281, 929, 313)
# Right Cheek Rect: (983, 280, 1041, 312)
# Left Cheek Rect: (871, 281, 929, 313)
# Right Cheek Rect: (983, 280, 1041, 312)
# Left Cheek Rect: (871, 284, 930, 317)
# Right Cheek Rect: (983, 285, 1041, 317)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1042, 312)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1042, 312)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1041, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 280, 1042, 313)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (985, 280, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 313)
# Left Cheek Rect: (871, 284, 930, 317)
# Right Cheek Rect: (983, 284, 1042, 317)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 280, 1042, 312)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 312)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 312)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (871, 284, 929, 317)
# Right Cheek Rect: (984, 284, 1041, 317)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (874, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (871, 284, 929, 316)
# Right Cheek Rect: (983, 284, 1041, 317)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (983, 284, 1041, 316)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (983, 285, 1041, 317)
# Left Cheek Rect: (873, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (870, 283, 929, 317)
# Right Cheek Rect: (983, 284, 1041, 317)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 280, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (983, 284, 1041, 317)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (870, 284, 928, 317)
# Right Cheek Rect: (983, 283, 1041, 316)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (982, 283, 1041, 316)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (982, 281, 1042, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (982, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 282, 1041, 313)
# Left Cheek Rect: (870, 283, 929, 317)
# Right Cheek Rect: (983, 283, 1041, 316)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 282, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 313)
# Right Cheek Rect: (984, 282, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (984, 282, 1042, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 282, 1042, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 282, 1044, 314)
# Left Cheek Rect: (869, 284, 928, 317)
# Right Cheek Rect: (983, 283, 1042, 316)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (874, 281, 932, 314)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (874, 281, 932, 314)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (983, 283, 1041, 316)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 282, 1045, 314)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 282, 1045, 314)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (986, 282, 1045, 314)
# Left Cheek Rect: (874, 281, 934, 314)
# Right Cheek Rect: (986, 282, 1045, 314)
# Left Cheek Rect: (874, 281, 934, 314)
# Right Cheek Rect: (986, 282, 1045, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (986, 282, 1045, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (986, 282, 1045, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (986, 281, 1045, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (987, 282, 1046, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (987, 281, 1046, 313)
# Left Cheek Rect: (871, 284, 929, 317)
# Right Cheek Rect: (983, 283, 1041, 316)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (987, 282, 1046, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (987, 282, 1046, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (987, 281, 1046, 314)
# Left Cheek Rect: (875, 281, 935, 314)
# Right Cheek Rect: (987, 282, 1046, 314)
# Left Cheek Rect: (876, 281, 934, 314)
# Right Cheek Rect: (987, 282, 1046, 314)
# Left Cheek Rect: (876, 281, 935, 314)
# Right Cheek Rect: (988, 282, 1046, 314)
# Left Cheek Rect: (876, 281, 935, 314)
# Right Cheek Rect: (988, 282, 1047, 314)
# Left Cheek Rect: (876, 281, 934, 314)
# Right Cheek Rect: (988, 282, 1046, 314)
# Left Cheek Rect: (876, 281, 935, 313)
# Right Cheek Rect: (988, 282, 1046, 314)
# Left Cheek Rect: (876, 281, 934, 313)
# Right Cheek Rect: (987, 281, 1046, 314)
# Left Cheek Rect: (871, 283, 929, 316)
# Right Cheek Rect: (982, 283, 1041, 315)
# Left Cheek Rect: (876, 281, 935, 313)
# Right Cheek Rect: (988, 281, 1046, 313)
# Left Cheek Rect: (875, 281, 934, 313)
# Right Cheek Rect: (987, 281, 1047, 314)
# Left Cheek Rect: (875, 281, 934, 313)
# Right Cheek Rect: (987, 281, 1046, 314)
# Left Cheek Rect: (876, 281, 934, 313)
# Right Cheek Rect: (986, 281, 1046, 314)
# Left Cheek Rect: (875, 281, 934, 313)
# Right Cheek Rect: (986, 281, 1046, 314)
# Left Cheek Rect: (875, 281, 934, 314)
# Right Cheek Rect: (986, 281, 1046, 314)
# Left Cheek Rect: (875, 281, 934, 313)
# Right Cheek Rect: (987, 281, 1046, 314)
# Left Cheek Rect: (875, 281, 934, 313)
# Right Cheek Rect: (986, 281, 1045, 314)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 281, 1045, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 281, 1045, 314)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (983, 282, 1042, 315)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (983, 284, 1041, 317)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 282, 1045, 314)
# Left Cheek Rect: (874, 280, 933, 313)
# Right Cheek Rect: (985, 281, 1045, 314)
# Left Cheek Rect: (874, 280, 933, 313)
# Right Cheek Rect: (985, 281, 1045, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1045, 313)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1045, 314)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (983, 283, 1042, 315)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 280, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (983, 282, 1043, 315)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (983, 282, 1042, 315)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (983, 282, 1042, 315)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (873, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 283, 930, 316)
# Right Cheek Rect: (983, 283, 1042, 315)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 314)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (872, 283, 930, 316)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (873, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (872, 283, 931, 316)
# Right Cheek Rect: (984, 283, 1043, 316)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (986, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1045, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 283, 932, 316)
# Right Cheek Rect: (984, 283, 1043, 316)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1045, 314)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (986, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (986, 281, 1044, 313)
# Left Cheek Rect: (873, 283, 932, 316)
# Right Cheek Rect: (984, 283, 1043, 316)
# Left Cheek Rect: (874, 281, 933, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (986, 281, 1044, 314)
# Left Cheek Rect: (874, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1045, 314)
# Left Cheek Rect: (873, 281, 933, 313)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (874, 282, 932, 314)
# Right Cheek Rect: (986, 282, 1043, 313)
# Left Cheek Rect: (874, 282, 933, 314)
# Right Cheek Rect: (986, 282, 1044, 313)
# Left Cheek Rect: (874, 282, 933, 314)
# Right Cheek Rect: (986, 281, 1044, 313)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (985, 282, 1043, 313)
# Left Cheek Rect: (873, 283, 932, 316)
# Right Cheek Rect: (985, 283, 1043, 316)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (983, 284, 1041, 316)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 282, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 282, 1043, 313)
# Left Cheek Rect: (872, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (874, 283, 933, 316)
# Right Cheek Rect: (986, 284, 1043, 316)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (873, 283, 933, 316)
# Right Cheek Rect: (986, 284, 1044, 316)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (875, 283, 933, 316)
# Right Cheek Rect: (985, 284, 1043, 316)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (874, 283, 933, 316)
# Right Cheek Rect: (986, 284, 1044, 316)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (874, 283, 933, 316)
# Right Cheek Rect: (986, 284, 1044, 316)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 283, 932, 316)
# Right Cheek Rect: (985, 283, 1044, 316)
# Left Cheek Rect: (873, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 314)
# Left Cheek Rect: (873, 283, 932, 316)
# Right Cheek Rect: (985, 283, 1044, 316)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (985, 281, 1044, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 283, 932, 315)
# Right Cheek Rect: (985, 283, 1044, 316)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (873, 283, 932, 316)
# Right Cheek Rect: (985, 283, 1044, 316)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (871, 282, 930, 315)
# Right Cheek Rect: (982, 281, 1042, 314)
# Left Cheek Rect: (871, 282, 930, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 282, 929, 315)
# Right Cheek Rect: (982, 282, 1041, 314)
# Left Cheek Rect: (871, 283, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 282, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 283, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 283, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 282, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (873, 283, 931, 315)
# Right Cheek Rect: (984, 283, 1043, 315)
# Left Cheek Rect: (870, 284, 929, 317)
# Right Cheek Rect: (982, 284, 1041, 316)
# Left Cheek Rect: (871, 283, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 283, 929, 315)
# Right Cheek Rect: (982, 282, 1042, 314)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (982, 282, 1042, 314)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (983, 282, 1042, 314)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (983, 282, 1042, 314)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (983, 282, 1042, 315)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (983, 282, 1042, 315)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (983, 282, 1043, 315)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 282, 1043, 315)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 283, 930, 316)
# Right Cheek Rect: (985, 283, 1043, 315)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 282, 1042, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 283, 931, 316)
# Right Cheek Rect: (985, 283, 1042, 315)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (871, 283, 931, 315)
# Right Cheek Rect: (985, 283, 1043, 315)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (985, 282, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (985, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 315)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (985, 282, 1043, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (984, 283, 1043, 315)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (985, 283, 1043, 314)
# Left Cheek Rect: (874, 282, 932, 314)
# Right Cheek Rect: (986, 283, 1043, 315)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (986, 283, 1044, 314)
# Left Cheek Rect: (873, 282, 932, 314)
# Right Cheek Rect: (986, 283, 1044, 314)
# Left Cheek Rect: (873, 282, 931, 314)
# Right Cheek Rect: (986, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (985, 283, 1042, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (985, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 282, 1043, 314)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 282, 1042, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (984, 281, 1043, 314)
# Left Cheek Rect: (872, 281, 931, 314)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 282, 1044, 314)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (873, 281, 932, 314)
# Right Cheek Rect: (984, 282, 1044, 314)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 282, 1044, 314)
# Left Cheek Rect: (872, 280, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (984, 281, 1044, 314)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 280, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (873, 280, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 280, 931, 313)
# Right Cheek Rect: (984, 281, 1044, 313)
# Left Cheek Rect: (872, 280, 931, 313)
# Right Cheek Rect: (984, 280, 1043, 313)
# Left Cheek Rect: (872, 280, 931, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 280, 930, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 280, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (871, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 313)
# Right Cheek Rect: (983, 281, 1043, 313)
# Left Cheek Rect: (871, 281, 930, 313)
# Right Cheek Rect: (983, 280, 1043, 313)
# Left Cheek Rect: (871, 281, 930, 313)
# Right Cheek Rect: (983, 280, 1043, 313)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (872, 281, 930, 313)
# Right Cheek Rect: (983, 280, 1042, 312)
# Left Cheek Rect: (871, 282, 930, 313)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 313)
# Right Cheek Rect: (984, 282, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 313)
# Right Cheek Rect: (985, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 313)
# Right Cheek Rect: (984, 282, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (869, 285, 928, 317)
# Right Cheek Rect: (982, 284, 1041, 316)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (872, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 313)
# Left Cheek Rect: (873, 280, 932, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 280, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 280, 1044, 312)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 280, 1043, 312)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (984, 283, 1043, 315)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (985, 280, 1044, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1044, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (985, 281, 1043, 313)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1043, 312)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (984, 281, 1043, 313)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 312)
# Left Cheek Rect: (874, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1043, 312)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (984, 283, 1042, 315)
# Left Cheek Rect: (873, 281, 932, 313)
# Right Cheek Rect: (984, 280, 1042, 312)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 280, 1042, 312)
# Left Cheek Rect: (873, 281, 931, 312)
# Right Cheek Rect: (984, 280, 1042, 312)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 280, 1042, 311)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (983, 279, 1042, 311)
# Left Cheek Rect: (873, 281, 931, 313)
# Right Cheek Rect: (984, 280, 1042, 311)
# Left Cheek Rect: (873, 281, 930, 312)
# Right Cheek Rect: (983, 280, 1041, 311)
# Left Cheek Rect: (872, 280, 930, 312)
# Right Cheek Rect: (984, 280, 1041, 311)
# Left Cheek Rect: (873, 280, 930, 311)
# Right Cheek Rect: (984, 280, 1041, 311)
# Left Cheek Rect: (873, 280, 930, 311)
# Right Cheek Rect: (984, 280, 1042, 311)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (983, 282, 1042, 315)
# Left Cheek Rect: (872, 280, 930, 311)
# Right Cheek Rect: (984, 280, 1042, 311)
# Left Cheek Rect: (872, 280, 930, 311)
# Right Cheek Rect: (984, 280, 1041, 311)
# Left Cheek Rect: (872, 280, 930, 311)
# Right Cheek Rect: (984, 280, 1040, 311)
# Left Cheek Rect: (872, 279, 930, 310)
# Right Cheek Rect: (983, 279, 1040, 310)
# Left Cheek Rect: (872, 279, 930, 310)
# Right Cheek Rect: (983, 280, 1041, 311)
# Left Cheek Rect: (872, 279, 930, 310)
# Right Cheek Rect: (982, 279, 1040, 310)
# Left Cheek Rect: (872, 279, 930, 310)
# Right Cheek Rect: (983, 279, 1041, 310)
# Left Cheek Rect: (872, 279, 930, 311)
# Right Cheek Rect: (982, 279, 1041, 310)
# Left Cheek Rect: (872, 279, 930, 311)
# Right Cheek Rect: (983, 278, 1041, 310)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 310)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (983, 283, 1041, 315)
# Left Cheek Rect: (871, 279, 929, 310)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 279, 929, 310)
# Right Cheek Rect: (982, 278, 1040, 309)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (981, 278, 1041, 309)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 280, 929, 311)
# Right Cheek Rect: (981, 279, 1041, 310)
# Left Cheek Rect: (871, 280, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 310)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 280, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 310)
# Left Cheek Rect: (871, 282, 930, 315)
# Right Cheek Rect: (983, 282, 1042, 315)
# Left Cheek Rect: (871, 280, 930, 311)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 280, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (982, 278, 1041, 309)
# Left Cheek Rect: (871, 279, 929, 311)
# Right Cheek Rect: (983, 279, 1041, 310)
# ...
# Left Cheek Rect: (871, 281, 929, 313)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (872, 283, 930, 316)
# Right Cheek Rect: (984, 285, 1043, 317)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (872, 284, 931, 316)
# Right Cheek Rect: (984, 284, 1043, 316)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (985, 284, 1043, 316)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (869, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (871, 283, 930, 315)
# Right Cheek Rect: (985, 284, 1043, 316)
# Left Cheek Rect: (868, 281, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 281, 927, 314)
# Right Cheek Rect: (980, 280, 1040, 313)
# Left Cheek Rect: (869, 281, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (868, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (868, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (868, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (980, 280, 1039, 313)
# Left Cheek Rect: (868, 282, 927, 314)
# Right Cheek Rect: (980, 280, 1040, 313)
# Left Cheek Rect: (868, 282, 927, 314)
# Right Cheek Rect: (980, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (980, 280, 1040, 313)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (985, 284, 1043, 316)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (868, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (869, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1042, 313)
# Left Cheek Rect: (870, 281, 929, 313)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (984, 284, 1043, 316)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 313)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (872, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (985, 284, 1043, 317)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (983, 281, 1041, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1041, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 281, 1041, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (983, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 283, 930, 316)
# Right Cheek Rect: (984, 284, 1042, 317)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1040, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 281, 1040, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1040, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 281, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1040, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1040, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (872, 283, 930, 316)
# Right Cheek Rect: (984, 284, 1042, 317)
# Left Cheek Rect: (871, 284, 929, 317)
# Right Cheek Rect: (983, 285, 1041, 317)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (983, 281, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (872, 284, 930, 316)
# Right Cheek Rect: (984, 284, 1042, 317)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (872, 284, 930, 317)
# Right Cheek Rect: (983, 284, 1041, 317)
# Left Cheek Rect: (869, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 281, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 281, 928, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (872, 283, 930, 317)
# Right Cheek Rect: (984, 284, 1042, 317)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 927, 314)
# Right Cheek Rect: (981, 280, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 280, 1041, 313)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (981, 281, 1040, 313)
# Left Cheek Rect: (869, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1041, 314)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 281, 1041, 314)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (981, 281, 1041, 314)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 284, 930, 317)
# Right Cheek Rect: (984, 284, 1041, 317)
# Left Cheek Rect: (869, 282, 928, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (869, 282, 928, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (869, 282, 928, 314)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (870, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1041, 314)
# Left Cheek Rect: (869, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1041, 314)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (981, 281, 1040, 314)
# Left Cheek Rect: (870, 282, 928, 314)
# Right Cheek Rect: (981, 281, 1040, 314)
# Left Cheek Rect: (870, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1040, 314)
# Left Cheek Rect: (870, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1040, 314)
# Left Cheek Rect: (870, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1040, 314)
# Left Cheek Rect: (871, 284, 930, 318)
# Right Cheek Rect: (983, 284, 1042, 317)
# Left Cheek Rect: (870, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1040, 314)
# Left Cheek Rect: (869, 282, 928, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (870, 282, 928, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (870, 282, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (870, 282, 928, 315)
# Right Cheek Rect: (981, 281, 1041, 314)
# Left Cheek Rect: (870, 282, 929, 315)
# Right Cheek Rect: (982, 281, 1041, 314)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (871, 284, 929, 318)
# Right Cheek Rect: (984, 284, 1041, 317)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 281, 1041, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 929, 314)
# Right Cheek Rect: (982, 280, 1041, 313)
# Left Cheek Rect: (871, 281, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 280, 1041, 313)
# Left Cheek Rect: (871, 283, 930, 317)
# Right Cheek Rect: (983, 284, 1042, 317)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 931, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (871, 284, 930, 318)
# Right Cheek Rect: (983, 284, 1042, 317)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 315)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 315)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 283, 930, 315)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (871, 284, 930, 318)
# Right Cheek Rect: (983, 284, 1042, 318)
# Left Cheek Rect: (872, 282, 930, 315)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (984, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 314)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (872, 282, 930, 314)
# Right Cheek Rect: (983, 281, 1042, 313)
# Left Cheek Rect: (870, 282, 929, 314)
# Right Cheek Rect: (983, 280, 1042, 313)
# Left Cheek Rect: (871, 284, 930, 318)
# Right Cheek Rect: (983, 284, 1042, 317)

# %%
## Print sample of the combined RGB signals
print("Sample of the Combined RGB Signals:")
print(len(combined_r_signal))
# Out:
# Sample of the Combined RGB Signals:
# 1799

# %%
# Create a time array based on the sampling rate and the number of samples
time_rgb = np.arange(len(combined_r_signal)) / fs

# Plot the combined RGB signals
plt.figure(figsize=(12, 6))
plt.plot(time_rgb, combined_r_signal, label='Combined R Signal', color='red')
plt.plot(time_rgb, combined_g_signal, label='Combined G Signal', color='green')
plt.plot(time_rgb, combined_b_signal, label='Combined B Signal', color='blue')
plt.xlabel('Time (s)')
plt.ylabel('Signal Value')
plt.title('Combined RGB Signals')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Process the RPPG signal
# Doing the RPPG process stuff ayaya

# %%
## Calculating the RPPG Signal
rgb_signals = np.array([combined_r_signal, combined_g_signal, combined_b_signal])
rgb_signals = rgb_signals.reshape(1, 3, -1)
rppg_signal = POS(rgb_signals, fps=30)
rppg_signal = rppg_signal.reshape(-1)

# Show the RPPG Signal
plt.figure(figsize=(20, 5))
plt.plot(rppg_signal, color='black')
plt.title('rPPG Signal')
plt.tight_layout()
plt.show()

# %%
## Print the len of RPPG signal
print(len(rppg_signal))
# Out:
# 1799

# %% [markdown]
# ## Post Pre-processing Signal RPPG
# Post processing stuff

# %%
def preprocess_ppg(signal, fs = 30):
    """ Computes the Preprocessed PPG Signal, this steps include the following:
        1. Moving Average Smoothing
        2. Bandpass Filtering
        
        Parameters:
        ----------
        signal (numpy array): 
            The PPG Signal to be preprocessed
        fs (float): 
            The Sampling Frequency of the Signal
            
        Returns:
        --------
        numpy array: 
            The Preprocessed PPG Signal
    
    """ 

    ## Moving Average Smoothing
    window = int(fs * 0.15)  # 150ms window
    smoothed_signal = np.convolve(signal, np.ones(window)/window, mode='same')

    b, a = scipy.signal.butter(3, [0.8, 2.0], btype='band', fs=fs)
    filtered = scipy.signal.filtfilt(b, a, smoothed_signal)
    
    # Additional lowpass to remove high-frequency noise
    b2, a2 = scipy.signal.butter(3, 2.5, btype='low', fs=fs)
    filtered = scipy.signal.filtfilt(b2, a2, filtered)
    
    # Moving average smoothing
    window = int(fs * 0.15)  # 150ms window
    filtered_signal = np.convolve(filtered, np.ones(window)/window, mode='same')

    return filtered_signal

# %%
## Filter RPPG Signal
preprocessed_signal = preprocess_ppg(rppg_signal, fs=30)

## Show the Filtered RPPG Signal
fig, ax = plt.subplots(2, 1, figsize=(20, 6))
ax[0].plot(rppg_signal, color='black')
ax[0].set_title('rPPG Signal - Before Filtering')
ax[1].plot(preprocessed_signal, color='black')
ax[1].set_title('rPPG Signal - After Filtering')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Let's obtain the PPG

# %%
## Path to GT
gt_path = "../Physio-Itera/Dataset/tryx6/vernier/tryx6_vernier_ecg.csv"

## Since it have two columns, date and value, we will use the value column
gt_ppg = pd.read_csv(gt_path, usecols=[1], header=None).values

## Flatten the GT PPG
gt_ppg = gt_ppg.flatten()

## Print the first 5 rows of the second columns
print(len(gt_ppg))
# Out:
# 12000

# %% [markdown]
# ## Downlsampling the GT to match with 30 Hz
# Since the original sampling rate is 200Hz, downsample this to 30Hz to match with the Video

# %%
## Downsampling the GT from 200 Hz to 30 Hz
original_fs = 200
new_fs = 30

## Downsampling the GT PPG Signal
gt_ppg = scipy.signal.resample(gt_ppg, int(len(gt_ppg) * new_fs / original_fs))

## Print the len of GT PPG
print(len(gt_ppg))

plt.figure(figsize=(12, 6))
plt.plot(gt_ppg, label='GT_PPG')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('ECG Signal at 30 Hz Sampling Rate')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1800

# %%
## print shape of gt signal
print(gt_ppg.shape)
# Out:
# (1800,)

# %%
## Post-Processing GT Signal
gt_ppg = preprocess_ppg(gt_ppg, fs=30)

## Show the Filtered GT Signal
plt.figure(figsize=(20, 5))
plt.plot(gt_ppg, color='black')
plt.title('GT Signal - Before Filtering')
plt.tight_layout()
plt.show()

# %%
## Finds the Peaks from the Preprocessed Signal and Ground Truth
rppg_peaks, _  = scipy.signal.find_peaks(preprocessed_signal)
gt_peaks, _ = scipy.signal.find_peaks(gt_ppg)

## Print the Peaks
print(f"Number of Peaks in rPPG Signal: {len(rppg_peaks)}")
print(f"Number of Peaks in Ground Truth: {len(gt_peaks)}")   

## Create the linspace for duration
duration = 120 # 120 seconds
time = np.linspace(0, duration, len(preprocessed_signal))

## Plot the Signal
plt.figure(figsize=(20, 5)) 
plt.plot(preprocessed_signal, color='black', label='rPPG Signal')
plt.plot(rppg_peaks, preprocessed_signal[rppg_peaks], "x", color='red', label='rPPG Peaks')
plt.plot(gt_ppg, color='blue', label='Ground Truth')
plt.plot(gt_peaks, gt_ppg[gt_peaks], "x", color='green', label='Ground Truth Peaks')
plt.title('rPPG Signal vs Ground Truth')
plt.legend(['rPPG Signal', 'rPPG Peaks', 'Ground Truth', 'Ground Truth Peaks'])
# plt.xlabel('Time (s)')
plt.xlabel("Samples")
plt.ylabel('Amplitude')
plt.legend()
plt.show()
# Out:
# Number of Peaks in rPPG Signal: 89
# Number of Peaks in Ground Truth: 98
